# %% [markdown]
# # 01 Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# df = pd.read_csv(r'/Users/Dom/Documents/Instacart Basket Analysis/02 Data/Original Data/orders.csv',index_col = False)

# %%
dfsampleimp = pd.read_csv(r'/Users/Dom/Documents/Instacart Basket Analysis/03 Scripts/sample.csv',index_col = False)

# %%
dfsampleimp.shape
# Out:
# (10000, 8)

# %%
dfsampleimp.head(30)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0      3098739   3370853   186861    prior             8          5
# 1       189466   2054041    11457    prior            17          1
# 2      2414520    433512   145285    prior            30          1
# 3       498382    765069    30056    prior            72          3
# 4       884731   3278091    53153    prior             7          2
# 5      3400469   2241880   204930    prior             8          2
# 6        53253   2350754     3310    prior             2          2
# 7      1000802   2061339    60134    prior            10          4
# 8      3256063   3286021   196243    prior             5          0
# 9      3148396   1177150   189851    prior            21          3
# 10      237650    400354    14412    prior            21          0
# 11      457983   1649749    27574    prior            35          5
# 12     2031655   1457461   122048    prior             9          6
# ...

# %%
df.tail()
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0

# %%
dfsampleimp.shape
# Out:
# (10000, 8)

# %%
dfsampleimp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              10000 non-null  int64
#  1   order_id                10000 non-null  int64
#  2   user_id                 10000 non-null  int64
#  3   eval_set                10000 non-null  object
#  4   order_number            10000 non-null  int64
#  5   order_dow               10000 non-null  int64
#  6   order_hour_of_day       10000 non-null  int64
#  7   days_since_prior_order  9354 non-null   float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 625.1+ KB

# %%
dfsampleimp.dtypes
# Out:
# Unnamed: 0                  int64
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
dfsampleimp.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'user_id', 'eval_set', 'order_number',
#        'order_dow', 'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
dfsampleimp.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number     order_dow  \
# count  1.000000e+04  1.000000e+04   10000.00000   10000.00000  10000.000000
# mean   1.704034e+06  1.710455e+06  102587.13680      17.04020      2.747800
# std    9.887724e+05  9.914211e+05   59604.60914      17.79187      2.040346
# min    3.310000e+02  4.700000e+01      27.00000       1.00000      0.000000
# 25%    8.470942e+05  8.519430e+05   50903.50000       5.00000      1.000000
# 50%    1.706401e+06  1.700560e+06  102446.50000      11.00000      3.000000
# 75%    2.568720e+06  2.567440e+06  154558.25000      23.00000      5.000000
# max    3.420325e+06  3.420912e+06  206162.00000     100.00000      6.000000
#
#        order_hour_of_day  days_since_prior_order
# count       10000.000000             9354.000000
# mean           13.521500               11.120056
# std             4.209003                9.184078
# min             0.000000                0.000000
# ...

# %%
path = r'/Users/Dom/Documents/Instacart Basket Analysis'

# %%
df = pd.read_csv(os.path.join(path, '03 Scripts', 'sample.csv'), nrows = 10000)

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(path, '03 Scripts', 'sample.csv'), usecols = vars_list)

# %%
## Step 6 - Print First 5 Rows of DataFrame
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3370853   186861             8          5                 13
# 1   2054041    11457            17          1                 12
# 2    433512   145285            30          1                 11
# 3    765069    30056            72          3                 22
# 4   3278091    53153             7          2                 16
#
#    days_since_prior_order
# 0                    30.0
# 1                     2.0
# 2                     7.0
# 3                     1.0
# 4                    30.0

# %%
## Step 7
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)
df_prods.shape
# Out:
# (49693, 5)

# %%
## Step 8 - Print the first 20 rows & last 35 Rows

df_prods.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %%
df_prods.tail(35)
# Out:
#        product_id                                       product_name  \
# 49658       49654                   Teriyaki Sauce, Sesame, Original
# 49659       49655                                        Apple Cider
# 49660       49656                         Masada Kosher Pocket Bread
# 49661       49657                                  Cabernet Tomatoes
# 49662       49658                         Brie with Herbs Foil Wedge
# 49663       49659                            Organic Creamed Coconut
# 49664       49660                        Professionals Sleek Shampoo
# 49665       49661                                              Porto
# 49666       49662                       Bacon Cheddar Pretzel Pieces
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49668       49664                     Lemon Cayenne Drinking Vinegar
# 49669       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49670       49666                      Ginger Snaps Snacking Cookies
# ...

# %%
## Step 9

df_prods.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
## Step10

df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# # Step 11 Answer
# What is the maximum value of the "aisle_id" column? The answer: 134
# What is the data type of the "department_id" column? Answer: integer
